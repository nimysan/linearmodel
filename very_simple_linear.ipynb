# %%
from sklearn import linear_model
import numpy as np

# %%
reg = linear_model.LinearRegression()

# %%
import random
x = np.random.randint(100,200,size=(20,10))
# print(x)
# print(x[:,1])

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
#x = np.arange(-10, 10, 1).reshape(-1,1)
print(x)
#print(x)
y = [1.2,3.3,4.4,123,-300,1,4,5,6,7,8,2,3,5,34,123,567,23,2,-3]
reg.fit(x,y)
# Out:
# [[194 195 195 148 153 178 145 113 128 144]
#  [167 174 127 125 105 115 137 111 145 100]
#  [109 100 152 118 162 158 180 119 164 110]
#  [117 180 171 174 128 196 158 152 122 194]
#  [167 129 108 181 124 157 113 187 178 146]
#  [139 107 157 187 149 124 194 190 124 146]
#  [112 152 199 193 160 169 198 145 188 144]
#  [130 188 181 162 127 174 129 194 190 173]
#  [196 157 183 143 181 177 166 195 163 117]
#  [165 148 173 150 127 173 165 188 180 179]
#  [160 170 153 152 155 167 136 134 162 144]
#  [199 111 121 169 131 191 124 162 127 177]
#  [123 185 182 178 149 199 123 105 179 138]
#  [124 176 106 127 127 167 103 167 181 196]
#  [111 127 106 119 184 127 173 173 192 182]
#  [188 153 169 158 176 156 187 131 182 193]
#  [185 110 130 167 121 191 118 100 192 162]
#  [120 188 172 190 141 156 114 187 188 144]
#  [114 180 146 170 188 129 146 168 158 103]
#  [115 146 114 155 145 189 161 116 156 173]]
# LinearRegression()

# %%
# print(2)
print("the coef is %s", reg.coef_)  # 非负最小二乘法 nnls
y2=reg.predict([[194,195,95,148,153,178,145,113,128,144]]) #safe_sparse_dot 推理就是做了一个矩阵乘法 a @ b
print(y2)
#y1 = reg.predict(x)
# Out:
# the coef is %s [ 0.15974053 -2.45113283  2.76972504 -0.20907228  0.59152912 -1.52599489
#  -2.26546962 -2.60004721  0.65887944  2.26907217]
# [-171.91660382]

# %%
print(np.dot(2,4))
from numpy import array,dot
a=array([[1,2],
        [1,2]])
b=array([[5,6],
        [5,6]])
print(a@b)
#print(dot(a,b))
# Out:
# 8
# [[15 18]
#  [15 18]]

# %% [markdown]
# > 这里是学习了一个一元线性啊， 如何变成2呢？

# %%
ax = plt.axes(projection='3d')  # 设置三维轴
# ax.scatter3D(X, Y, Z)
#ax.plot3D(x[:,0],x[:1], y1,label="linear")
# colors = np.random.rand(50)
ax.scatter3D(x[:,0],x[:1], y, alpha=0.5,c="g", label="data")
plt.xlabel("x")
plt.ylabel("y")
# plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 5
#       1 ax = plt.axes(projection='3d')  # 设置三维轴
#       2 # ax.scatter3D(X, Y, Z)
#       3 #ax.plot3D(x[:,0],x[:1], y1,label="linear")
#       4 # colors = np.random.rand(50)
# ----> 5 ax.scatter3D(x[:,0],x[:1], y, alpha=0.5,c="g", label="data")
#       6 plt.xlabel("x")
#       7 plt.ylabel("y")
#
# File ~/miniconda3/envs/RpML/lib/python3.10/site-packages/matplotlib/__init__.py:1452, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1449 @functools.wraps(func)
#    1450 def inner(ax, *args, data=None, **kwargs):
#    1451     if data is None:
# -> 1452         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1454     bound = new_sig.bind(ax, *args, **kwargs)
#    1455     auto_label = (bound.arguments.get(label_namer)
# ...

# %%
#
